# %%
import tiktoken
encoding = tiktoken.get_encoding("cl100k_base")
token=100000
encoding.decode_single_token_bytes(token)
# Out:
# b'IClient'

# %%
from langchain_community.document_loaders import PyPDFLoader
file_path="~/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf"
loader = PyPDFLoader(file_path)
pages = []
async for page in loader.alazy_load():
    pages.append(page)

# %%
pages
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 0, 'page_label': '1'}, page_content='今回もAnnofabツールを使用した路面地物のアノテーション作業ですが、今までの内容と異なる点があります。\n前回アノテーション作業（DTS-PARMS-湘南藤沢_20230130）との相違点を以下にまとめました。\n■今回のアノテーション目的\n・仕様簡易化の取り組み\n・道路のどの位置を走るべきかを示すレーンレベル経路、および交差点接続関係を新たに整備\n■前回アノテーションとの相違点\n＃ 前回 今回\n1 仕様 区画線：ポリライン 取得対象の地物は同じだが、ラベルが一部統合し入力属性値が少なくなります\n・ラベル／属性値 0x01-外側線 0x81-区画線\u3000に統合\n0x02-車線境界線\n0x03-上下線境界線\n0x04-指導導流線\n属性値：「線種」「線色」「種別」「位置」「進行方向」 属性値：「線種」「線色」のみ\n0x05-停止線(交差点内) 0x82-停止線\u3000\u3000に統合\n0x06-停止線(交差点外)\n属性値：「線種」「線色」「種別」 属性値：「線種」「線色」のみ\n0x08-路肩縁 0x84-路肩縁\n属性値：「種別」 （入力属性値なし）\n・その他の変更点 ・交差点などカーブ・U字で区切る（進行方向：向きなし） ・属性「進行方向」自体が無いため区切る必要なし\n・ゼブラ縁取得（交差点内のダイヤモンド縁はポリライン取得不要） ・ゼブラ縁取得（交差点内のダイヤモンド縁も取得）\n・停止線の描画順は進行方向に対し左から右 ・停止線の描画順は特に問わない\n・２本以上のポールを路肩縁として取得 ・１本以上のポールを路肩縁として取得\n・破線と実線は吸着しない ・破線と実線は、線端が延長上にある場合は連続性をもたせ吸着する\n・太破線はポリゴン＋両脇をポリラインで取得 ・太破線として区別せず区画線の破線と同じ扱い：中心部をポリラインで取得\n・太破線⇔ゼブラゾーン部分については、ゼブラゾーンまでポリラインを延長\n領域地物：ポリゴン ポリゴン地物は全て取得不要です\n0x01-横断歩道 廃止\n0x02-ゼブラゾーン\n0x03-ダイヤモンド\n0x04-中央分離帯\n0x05-交差点領域\n0x06-二重線・太線\n0x07-交差点内経路\n0x08-停止禁止領域\n0x09-自転車横断帯\n0x10-矢印\n仮想区画線：ポリライン 区画線が部分的に途切れる箇所の補間として新たに追加\n・ラベル／属性値 （なし） 0xFF-仮想区画線\n（入力属性値なし）\n交差点間レーンNW：ポリライン 道路のどの位置を走るべきかを示すレーンレベル経路として新たに追加\n・ラベル／属性値 （なし） 交差点間レーンNW\n属性値：「進行方向」「レーン地物種別」\n交差点接続関係：ポリライン レーンNWからつながる交差点内の接続関係を新たに追加\n・ラベル／属性値 （なし） 交差点接続関係\n（入力属性値なし）\n2 アノテーションポリシー 重複レイヤの画像にて、同一箇所の同一取得対象地物に対してはいづれか\nのレイヤ１つを取得（地物の取得漏れは厳禁）\n各レイヤ全ての取得対象地物を取得\n参考 [前回プロジェクトLINK] DTS-PARMS-湘南藤沢_20230130'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 1, 'page_label': '2'}, page_content='202311 - 0. 作業概要 \n作業概要 \n概要 \n 今回のアノテーションは、全 3 フェーズで行い、地物、交差点間レーン NW、交差点接続関係\nの順にアノテーションを行います。 \n 教師付け、検査までの作業を行い、受入作業は行いません。受入のタスクは次フェーズ開始\nのタイミングで差し戻しが行われます。差し戻されたタスクに対して、次フェーズのアノテーショ\nンを行います。 \n \n図： 1 アノテーションフロー'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 2, 'page_label': '3'}, page_content='地物 アノテーション例 \n 区画線、停止線、路肩縁、仮想区画線、対象外領域のアノテーションを行います。 \n \n交差点間レーン NW アノテーション例 \n 交差点間レーンNW、対象外領域のアノテーションを行います。'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 3, 'page_label': '4'}, page_content='交差点接続関係 アノテーション例 \n 交差点接続関係（交差点での交差点間レーン NW 同士の接続関係）、対象外領域のアノテー\nションを行います。 \n \nアノテーション仕様 \n• 202311 - 1.1. アノテーション仕様 - 地物 \n• 202311 - 1.2. アノテーション仕様 - 交差点間レーンNW \n• 202311 - 1.3. アノテーション仕様 - 交差点接続関係'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 4, 'page_label': '5'}, page_content='その他 \n 以降は本プロジェクト向けに追加されているエディタ機能の説明です。 \nベクタの入力・編集機能の強化（重要！） \nアノテーションの頂点を移動中、 Shift + Alt を押すと、（押している間）近くの頂点に吸着しま\nす。 \nぴったり重なった頂点は、 Shift + Alt を押しながらドラッグを開始することで、同時に移動する\nことができます。 \n \n各種調整機能 （重要！） \n環境パネルやヘルプパネルと同じ場所にある オプションパネル で各種判定や表示の大きさ\n調整することができます。 \n• 表示や動作に問題がなければ、周辺画像の読み込みの設定を 2000px 程度 にしてく\nださい。'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 5, 'page_label': '6'}, page_content='カラーオルソ画像の表示 （重要！） \n 区画線の色を判断する場合はカラーオルソ画像を補助情報から表示してください。 \n \nポリライン分割機能 \n 本プロジェクトでは属性が変わる箇所でポリラインを分割する必要があります。 「ポリライン\n分割」ラベル で作図済のポリラインと交差するように作図すると、そのポリラインを交差点で分\n割することができます。 \n \n点列の反転機能（向きの反転） \n 本プロジェクトはポリラインの描画順が重要となります。ポリラインの描画向き（始点終点）を\n反転させたい場合、 アノテーション選択後に「Ctrl」、「M」の同時押し (あるいは「編集」タブの\n「操作」パネル内の「向きを反転」ボタン押下)で反転することができます。'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 6, 'page_label': '7'}, page_content='頂点の挿入・削除 \n 作図時の微調整で頂点を挿入・削除させたい場合、 アノテーションの該当頂点で右クリック\nで表示されるメニューから「選択箇所に頂点を挿入」または「選択箇所に頂点を削除」を選\n択 (あるいは「編集」タブの「操作」パネル内の「頂点挿入」「頂点削除」ボタン押下)で編集する\nことができます。 \n \n \n \nツールチップの属性表示設定'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 7, 'page_label': '8'}, page_content='本プロジェクトは、大量のアノテーションの属性を確認する必要があります。各々（教師付\nけ、受入ごとなど）で分かりやすいツールチップの属性表示設定にするのがオススメです。 \n \nツールチップの表示位置 \n エディタ上で、 「Alt」、「Shift」、「N」の 3 キーを同時押し すると、ツールチップの表示位置を\n始点（標準）、終点と切り替えることが出来ます。 \n 本プロジェクトは画像をスライドさせながらアノテーションする事が多くなるため、教師付け時\nのツールチップ表示位置は終点にするのがオススメです。 \n自動スクロールのオフ（重要！） \n 本プロジェクトは画像をスライドさせながらアノテーションすることが多くなるため、アノテーシ\nョン選択時の自動スクロールが邪魔になることが多いです。 \n  表示パネルの自動スクロールのチェックをオフ にするのがオススメです。'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 8, 'page_label': '9'}, page_content='ポリラインアノテーションの方向可視化 \n表示パネルの線の向き非表示のチェックをオフ にすると、矢印やレーンリンクの線の向きを表\n示できます。 \n \n \n属性値の可視化 \nアノテーションにカーソルをあわせると、 アノテーションが少し暗くなり、カーソル近くに属性表\n示が出ます。 \n表示パネルの ツールチップ追従 でオフにすることができます。'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 9, 'page_label': '10'}, page_content='複数選択による編集・削除 \n選択モードで矩形選択、Ctrl + マウス選択 でアノテーションを複数選択することができます。 \n \n \nアノテーション一覧パネルでの一括操作 \nすべて展開・すべて畳むボタン、その左にある目玉ボタンで全ラベルを表示・非表示 で一括で\n操作することができます。 \n \n指定ラベル以外の一括非表示 \nAlt + 目玉クリック で、そのラベル以外をまとめて表示・非表示にすることができます。'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 10, 'page_label': '11'}, page_content='同一領域・隣接領域のアノテーション対応 \n作業中の画像に隣接する画像とアノテーションも表示します。 \n同一領域に対して別画像やアノテーションが登録されている場合、 レイヤーパネル で表示を\n切り替えることができます。 \nまた画像上で右クリックすると該当箇所に所属するタスクリストが表示されます（タスク名を選\n択することでタスク一覧画面を表示可）'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 11, 'page_label': '12'}, page_content=''),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 12, 'page_label': '13'}, page_content='202311 - 1.1. アノテーション仕様 - 地物 \n概要 \nオルソ画像から道路上の地物（区画線、路肩縁、停止線）をアノテーション（線で描画し属性値\nを入力）します。 \n• 画像内のオルソ画像から判断できる地物を入力します \n• 道路自体の視認性が悪く（木、建物、構造物による隠れ、見切れ・途切れなど）アノテー\nション困難な領域や施設内など道路外の停止線などは、対象外領域としてポリゴンで\n入力します \nアノテーション前 アノテーション後 \n \n \n \n \n・区画線、路肩縁、停止線をポリラインで取得 \n・道路の途切れ部分は対象外領域をポリゴンで取得 \n \n \n \n \n・区画線、路肩縁、停止線をポリラインで取得 \n・施設内の停止線は対象外領域をポリゴンで取得 \n図： 1 アノテーション例   **青：区画線、緑：路肩縁、黄：停止線、赤：対象外領域'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 13, 'page_label': '14'}, page_content='ラベルの説明 \n0x01-区画線 \n• 車道と平行する区画線（外側線、車線境界線、上下線境界線、指導導流線）をポリライ\nンで入力します （概要の事例（青線）参照） \no 外側線：車両通行帯最外側線（道路または車道の路端寄りに引かれている区\n画線） \no 車線境界線：外側線と上下線境界線以外の車線境界線 \no 上下線境界線：上下線の境界の線 \no 指導導流線：交差点内（横断歩道以降）の外側線、停止線以外の線  \n\uf0a7 ゼブラゾーン、ダイヤモンド（交差点内のひし形のゼブラゾーン）の縁も\n入力対象とします \n• 連続性を持たせて入力を行います。但し、属性（線色や線種）が変化する場合は区切り\nます \n• 多重線の場合は、1 本ずつ全てポリライン入力します（3 本の多重線の時は 3 本ポリラ\nイン描画する） \n• 描画順は、タスク内での連続するひとつながりの区画線の描画順に一貫性を持たせる\nように入力します  \no 基本的には進行方向と合わせるようにしてください \no 進行方向に従うと描画順の一貫性を保てない場合、描画順は問いません  \n\uf0a7 一繋がりの路肩縁の進行方向が衝突する場合等 \no 進行方向が分からない場合は、タスク内で描画順が一貫性を持つようになって\nいれば描画順は問いません \no タスク境界（画像境界）で進行方向が分からない区画線の描画順に一貫性がな\nくとも構いません（ただし、タスク境界のポリラインは頂点を吸着機能で吸着させ\nてください） \n• 属性値について \no 線種 \n\uf0a7 実線… 対象が実線の場合に入力します \n\uf0a7 破線… 対象が破線の場合に入力します \n\uf0a7 不明… 線種の判断が難しい、もしくは上記以外の場合に入力します \no 線色 \n\uf0a7 白… 対象が白の場合に入力します \n\uf0a7 黄… 対象が黄の場合に入力します \n\uf0a7 不明… 線種の判断が難しい、もしくは上記以外の場合に入力します'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 14, 'page_label': '15'}, page_content='0x02-停止線 \n• 停止線をポリラインで入力します（概要の事例（黄線）参照） \n• 自転車専用道内にある停止線は入力しません \n• 描画順は問いません \n• 属性値について \no 線種 \n\uf0a7 実線… 対象が実線の場合に入力します \n\uf0a7 破線… 対象が破線の場合に入力します \n\uf0a7 不明… 線種の判断が難しい、もしくは上記以外の場合に入力します \no 線色 \n\uf0a7 白… 対象が白の場合に入力します \n\uf0a7 黄… 対象が黄の場合に入力します \n\uf0a7 不明… 線種の判断が難しい、もしくは上記以外の場合に入力します \n0x03-路肩縁 \n• 車道と歩道の境界（車道と歩道の境界が無い場合は道路の端）、中央分離帯、交\n通島、バイパスなどの仕切り（道路の端：路面と縁石の境目）、ポールやガードパ\nイプ、ガードレールなどの防護柵、暗渠の縁をポリラインで入力します（概要の事\n例（緑線）参照） \n• 中央分離帯の端も全て路肩縁を入力します \n• 上下道の境界に中央分離帯が存在せず上下線境界線のみで構成されている場\n合は路肩縁を入力しません \n• 連続性を持たせて入力を行います \n• 描画順は、原則として進行方向と合わせるようにし、タスク内での連続するひとつ\nながりの区画線の描画順に一貫性を持たせるように入力します  \no 進行方向が分からない場合は、タスク内で描画順が一貫性を持つようにな\nっていれば、描画順は問いません \no タスク境界（画像境界）で進行方向が分からない区画線の描画順に一貫性\nがなくとも構いません（ただし、タスク境界のポリラインは頂点を吸着機能\nで吸着させてください） \n＜道路上に直接設置されたポールやガードレールなどの防護柵について＞ \n• 道路上に直接設置された防護柵が入力対象（縁石の上のポールは入力不要） \n• 防護柵の脇に沿って隣接支柱を入力（防護柵の真上では無い） \n• 隣り合う柱をつなげて入力（ ポール1 本のみで存在する場合は点状のポリライン\n（付近に2 点打つ）で入力する ）'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 15, 'page_label': '16'}, page_content='• 車道側をポリラインで入力（車両が走行できる境目をアノテーションで入力したい） \n \n \nアノテーション前 アノテーション後 \n \n・ポール複数本 \n・車道と歩道の間にポールがある場合 \n \n⇒ポールに沿って車道側に取得'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 16, 'page_label': '17'}, page_content='・ポール１本 \n・車道と歩道の間にポールがある場合 \n \n⇒ポールに沿って車道側に取得 \n \n図： 2 \n仮想区画線（0xFF） \n• 道路標示で一連の地物（区画線、停止線、路肩縁）が途切れてしまう領域や、一連の\n地物とみなせ破線の間隔より大きく途切れがある場合に「仮想区画線」としてポリライ\nンで入力します  \no 横断歩道は直進向けのみ仮想区画線で補間（右左折向けの場合は補間不要） \no 途切れが長い距離の場合でも制限なく途切れを補間して繋ぎます \n• 仮想区画線は同じラベルの端点どうしを補間します \no [a] 区画線 –– 仮想区画線 ––[b] 区画線 ⇒[a] と [b]の端点を仮想区画線で補間 \no [a] 路肩縁 –– 仮想区画線 ––[b] 路肩縁 ⇒[a] と [b]の端点を仮想区画線で補間 \no [a] 区画線 –– 仮想区画線 ––[b] 路肩縁 ⇒[a] と [b]は仮想区画線で補間しない \no [a] 区画線 –– 仮想区画線 ⇒ [a]の延長上に同じラベルが無い場合は仮想区画線不要 \n• 横断歩道を跨いで仮想区画線を補間する場合は、横断歩道まで区画線が届いている\n場合のみ補間する（横断歩道に区画線が届いていない場合は補間不要） \nアノテーション例 備考 \n \n• 横断歩道（直進向け）で外側線\n（青線）が途切れている場合、\n仮想区画線(ピンク線)で補間'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 17, 'page_label': '18'}, page_content='• 「バス」路上停車帯で外側線(青\n線)が途切れている場合、仮想\n区画線(ピンク線)で補間 \n \n• 停止禁止部分（縞部分）で外側\n線（青線）が途切れている場\n合、仮想区画線（ピンク線）で補\n間 \n \n• バス停で外側線（青線）が大き\nく途切れている場合、仮想区画\n線（ピンク線）で補間 \n• 途切れの目安は破線 1 つ分よ\nりも大きい場合 \n \n• ひどい掠れでゼブラ縁（青線）\nが大きく途切れている場合、仮\n想区画線（ピンク線）で補間 \n• 途切れの目安は破線 1 つ分よ\nりも大きい場合 \n図： 3'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 18, 'page_label': '19'}, page_content='アノテーション対象外領域 \n• 以下に示す領域を対象外領域として入力します （概要の事例（赤枠）参照） \no アノテーション対象の地物が存在する車両の通る公道において、画質、視認性\nの問題で地物の作図やラベルの判断が困難な領域 \no 道路外領域（教習所、駐車場、公園、私有地 など）にアノテーション対象の地物\nが存在する場合 ⇒道路外における対象地物の誤検出を防ぐため \n• アノテーション対象の地物が存在しない領域には対象外領域の入力不要です \nアノテーション例 備考 \n \n• 駐車場において、区画線等のアノテーシ\nョン対象地物が存在しない領域は対象\n外領域の取得は不要 \n \n• 面的に画像が欠落している領域につい\nて対象外領域の取得は不要 \n• 見える範囲で周囲のアノテーション対象\nの地物へ入力する \n図： 4'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 19, 'page_label': '20'}, page_content='データ編集時の注意事項 （アノテーション全\n般） \n作図について \n• 必ず地物が存在する箇所に対し丁寧に描画して下さい  \no 「地物からずれて描画する」等、地物が無い場所に描画をすると学習データとし\nて精度が悪くなる為ご注意願います \n• 人目に地物が見える所については網羅的に地物（区画線、停止線、路肩縁）として入\n力します※同タスクに複数レイヤあるケースも基本的に全て取得する \n• 地物は基本的に視認できるところまでを入力します \n• 道路標示（横断歩道、停止禁止領域等）による区画線の途切れに対しては、直線の延\n長で繋がる場合は仮想区画線で繋ぎ入力します \n• その他原因による途切れ（有無不明、掠れ、マンホール等による途切れ）の場合 \no 破線１つ分の長さ程度の場合は、区画線で連続して描画 \no 破線１つ分より長い場合は、仮想区画線で描画 \no 判断が難しい場合は仮想区画線で描画 \n \n地物からずれて描画する例（悪い例＝緑線）'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 20, 'page_label': '21'}, page_content='アノテーション例 \n• 参考としていくつかの事例を示します \n画像例 アノテーション例 \n \n道路表示（横断歩道）による途切れ \n \n \n⇒直進部：仮想区画線（ピンク線）による補間あり \n**右左折部は補間不要 \n \n道路表示（横断歩道）による途切れ \n \n \n⇒直進部：仮想区画線（ピンク線）による補間あり \n**右左折部は補間不要 \n \n道路表示（横断歩道）による途切れ \n \n**右左折部は補間不要'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 21, 'page_label': '22'}, page_content='道路表示（横断歩道）による途切れ \n \n**右左折部は補間不要 \n \n区画線_実線の始終点について \n \n \n \n⇒線端から線端まで描画(青線) \n**上図のように区画線が横断歩道まで届いていない\n場合、仮想区画線で補間する必要ありません\n \n \n区画線_破線の始終点について \n \n⇒線端から線端まで連続性をもって描画(青線) \n \n部分的に画像に欠落があるケース \n \n \n \n \n⇒欠落部の大きさが破線１つ分より短い場合は区画\n線（青線）で連続して描画 \n**上図のように線種が実線かどうかの判断が難しい\n場合は線種＝不明'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 22, 'page_label': '23'}, page_content='交差点中央部のダイヤモンド \n \n⇒区画線（青線）で取得 \n図： 5'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 23, 'page_label': '24'}, page_content='破線の描画について \n• 破線は全体を連続して描写（破線どうしはつなげる） \n• 破線の始点終点は前後に実線がある場合は実線に合わせる（破線を延長し実線とつ\nなげる）  \no ただし、破線の延長上に実線の端点が無い場合は実線とつなげない \n• 前後に実線がない場合は破線の始終点に合わせる（破線の端まで） \n• 分合流のゼブラゾーンは、ゼブラゾーンまで延長する \n \n画像例 アノテーション例 \n \n \n \n破線どうしは連続して描画 \n \n実線との連続性があるケース \n  \n破線を延長し実線とつなげる'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 24, 'page_label': '25'}, page_content='バス停などの道路拡幅あり \n実線との連続性があるケース \n（破線の延長上に実線の端点がある） \n \n破線を延長し実線とつなげる \n \n \nバス停などの道路拡幅あり \n（破線の延長上に実線の端点が無い） \n破線と実線はつなげない \n \n \n別道路との交差部 \n（破線の延長上に実線の端点が無い） \n \n破線と実線はつなげない'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 25, 'page_label': '26'}, page_content='分合流のゼブラゾーン \n \n破線をゼブラゾーン（中央）まで延長する \n \n分合流のゼブラゾーン \n \n破線をゼブラゾーン（中央）まで延長する \n図： 6'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 26, 'page_label': '27'}, page_content='隣接画像間の頂点吸着について \n• 地物が画像を跨いで存在する場合、画像の範囲内を入力してください \n• 隣接画像側のアノテーションが既に存在する場合、端点を吸着するように入力してくだ\nさい  \no アノテーションの頂点を移動中、 Shift + Alt を押すと、（押している間）近くの頂\n点に吸着します。 \n \n図. 11: 隣接画像間の頂点吸着について'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 27, 'page_label': '28'}, page_content='202311 - 1.2. アノテーション仕様 - 交差点間\nレーン NW \n概要 \n道路上の区画線や路肩縁の中心線を交差点間レーンNW として入力します。 \nアノテーション前 アノテーション後 \n \n \n図： 1 アノテーション例    **オレンジ線：交差点間レーンNW \nラベルの説明 \n交差点間レーン NW \n• 車両通行帯にある区画線または路肩縁の中心線をポリラインで入力します \n• 描画順は重要です。描画順は車両の進行方向に沿って始点→終点とします（終点側：\n車両が進行する向き）  \no 進行方向の判断が難しい場所については描画順を任意として、進行方向に不\n明として入力します \n• 交差点間レーンNW は分割されていても問題ありませんが、端点同士が吸着するよう\nに入力します \n• 属性値について \no 進行方向 \n\uf0a7 順方向  \n\uf0a7 進行方向が順方向の場合に入力します \n\uf0a7 描画順で始点→終点（正）を表現します'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 28, 'page_label': '29'}, page_content='\uf0a7 両方向  \n\uf0a7 対面通行（無車線区間として描画時）、リバーシブルレーンの場\n合等で両方向に車両が走行可能な場合に入力します \n\uf0a7 描画順は問いません \n\uf0a7 不明  \n\uf0a7 進行方向が判断できない場合に入力します \no レーン地物種別 \n\uf0a7 一般  \n\uf0a7 無車線区間ではないと判断できる場合に入力します \n\uf0a7 無車線区間  \n\uf0a7 周囲の状況（道路標示、区画線等）から複数車線ある事が分か\nるが、車線を示す区画線が整備されていない場合に入力します \n\uf0a7 無車線区間と一般区間の境界の判断が難しい場合、厳密に境\n界を探る必要はなく、アノテーションの両端の端点のどちらかが\n無車線区間の領域である場合、そのアノテーションは無車線区\n間の属性を入力します \n\uf0a7 料金所 \n\uf0a7 料金所の料金支払いレーン（ETC レーン等）と判断できる場合に\n入力します \n\uf0a7 料金所前後に存在する事の多い区画線の無い道幅の広い領域\nは無車線区間として入力します \n\uf0a7 無車線区間と料金所の境界は直角に吸着して分岐・合流点をも\nたせます \n\uf0a7 踏切 \n\uf0a7 踏切内と判断できる場合に入力します \n\uf0a7 踏切が交差点内と接している場合、踏切内の交差点間レーン\nNW とその他の交差点レーンNW を交差点接続関係で結び入力\nします \n\uf0a7 踏切が交差点間と接している場合、一時停止線等があればそこ\nで区切り、なければ交差点間を吸着させて入力します \n\uf0a7 不明  \n\uf0a7 無車線区間かどうか判断に迷う場合に入力します'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 29, 'page_label': '30'}, page_content='区切り（端点）位置について \n• 交差点内は交差点間レーンNW を入力せず、区切る必要があります \n• 図. 2 に示す基準で区切り、複数該当する場合は優先順の順位に従います \n \n図： 2 区切り位置の優先順位  \n \n状況 画像例 アノテーション例 \n停止線\nが存在\nする場\n合 \n \n \n \n停止線まで入力'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 30, 'page_label': '31'}, page_content='横断歩\n道が存\n在する\n場合 \n \n \n \n横断歩道まで入力 \n隣接す\nる区画\n線に途\n切れが\nある場\n合 \n \n \n別道路\nとの交\n差があ\nる場合'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 31, 'page_label': '32'}, page_content='隣接す\nる区画\n線に途\n切れが\nなく、別\n道路と\nの交差\nがある\n場合 \n \n \n隣接す\nる区画\n線が存\n在せ\nず、別\n道路と\nの交差\nがある\n場合 \n \n \n図： 3 区切り位置の入力例  \n \nレーン NW の分岐合流箇所について \n• 車線数が増減する場所（レーンNW の分岐・合流部）は、分岐・合流点（頂点を吸着さ\nせる）を持つように入力します \n• 分岐・合流部は道路幅の拡幅を含む場合と含まない場合で異なるアノテーション方法\nになる点に注意してください \n• 拡幅ありの場合  \no 車線幅が一定の所は通常通りに入力し、拡幅開始・終了の境界で区切る \no 周囲の区画線に沿って（なるべく平行に）境界の端点同士を繋ぎ入力します \no レーン地物種別は「一般」と入力します \no 拡幅があるバス停、非常駐車帯等の領域が区画線で区切られている場合は、\n分岐・合流部とみなして入力します \n• 拡幅なし（多くの場合は、無車線区間と一般区間の境界）、または拡幅しているかどう\nかわからない（滑らか等）場合  \no 一般区間と無車線区間の境界に直角の分岐・合流点位置を持ちます'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 32, 'page_label': '33'}, page_content='o 一般区間側の交差点間レーンNW を直角に曲げて入力します \n• 拡幅区間を複数タスクが跨ぐ場合  \no 拡幅区間内のアノテーション（直線で繋ぐ部分）はタスク間で分割せず、以下に\n従い入力します  \n\uf0a7 拡幅区間のアノテーションは、原則始点側のタスクで入力します \n\uf0a7 進行方向が両方向、不明の場合は、車線数が少ない側で入力します \n• 複数車線あり、車線数増減と関係の無い車線については区切りなど不要で通常通りに\n入力します \n状況 入力例 \n拡幅ありの場合 \n• 拡幅開始地点に分岐・合流\n点（頂点の吸着）を持つよう\nに入力します \n• アノテーションは分岐・合流ご\nとに分岐・合流点から新たに\n入力します \n• 周囲の区画線に沿って（なる\nべく平行に）入力します \n \n拡幅なしの場合 \n• 一般区間と無車線区間の\n境界に直角の分岐・合流点\n位置を持ちます \n• 一般区間側の\n交差点間レーン\nNW を直角に曲\nげて入力します \n \n車線幅が大きく変わらないのに車線数が突然変化する場合 \n図： 4 分岐・合流部の吸着例'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 33, 'page_label': '34'}, page_content='状況 画像例 アノテーション例 \n拡幅ありの場合 \n• 車線幅が一\n定の所は通\n常通りに入\n力し、拡幅\n開始・終了\nの境界で区\n切る \n• 境界の端点\n同士を周囲\nの区画線に\n沿って（なる\nべく平行に）\n繋ぎ入力し\nます \n• レーン地物\n種別は「一\n般」と入力し\nます'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 34, 'page_label': '35'}, page_content='拡幅があるバス\n停、非常駐車帯\n等 \n（区画線による\n区切りあり** 青\n線部分） \n \n \n \n拡幅なし（多くの\n場合は、無車線\n区間と一般区間\nの境界）、または\n拡幅しているか\nどうかわからな\nい（滑らか等）場\n合'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 35, 'page_label': '36'}, page_content='タスク間で拡幅\n区間を跨ぐ場合 \n \n \n \n車線数増減と関\n係の無い車線の\n場合 \n \n \n図： 5 分岐・合流部の入力例'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 36, 'page_label': '37'}, page_content='ガタツキを抑えて入力 \n• 交差点間レーンNW は、隣接する地物の中心線として入力しますが、外側線有無など\n隣接する地物の途切れや、区画線を伴わないバス停、停留所等による局所的な拡幅\nなどに合わせることでガタツキが発生してしまう場合、なるべくガタツキを抑えて入力し\nます\n  \no ただし、外側線など区画線を伴うバス停、非常駐車帯の場合は、分岐・合\n流として入力する必要がある点に注意してください \n• 実際に道路自体がデコボコしている場合はガタツキを持たせて入力して問\n題ありません \n状況 悪い例 良い例 \n外側線の\n有無によ\nるガタツ\nキを抑え\nる \n \n \n地物を伴\nわないバ\nス停拡幅\nはガタツ\nキを抑え\nる'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 37, 'page_label': '38'}, page_content='**注意） \n外側線な\nど地物を\n伴うバス\n停拡幅\nは、分\n岐・合流\nとして入\n力 \n－ \n \n**注意） \n減速を促\nすため等\nで実際に\n道路自体\nが凸凹し\nている場\n合はガタ\nツキを抑\nえなくて\n良い \n－ \n \n図： 6  ガタツキの入力例'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 38, 'page_label': '39'}, page_content='無車線区間 \n• 無車線区間の例とアノテーション方法を示します \n状況 画像例 アノテーション例 \n周囲の状況\n（道路標\n示、区画線\n等）から複\n数車線ある\n事が分かる\nが、車線を\n示す区画線\nが整備され\nていない場\n合 \n \n1 車線に矢印ペイントが 2 つある場合 \n \n \nオレンジ色の点線：拡幅部から停止線までを\n無車線区間とする \n道路標示か\nら分かる場\n合 \n・片側に対\nしてのみ停\n止線が存在\nするため、\n複数車線存\n在すること\nが分かる \n \n1 車線対面通行の場合'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 39, 'page_label': '40'}, page_content='作業タスク\nや隣接タス\nクから対象\nのレーン\nNW が無車\n線区間と分\nかる場合 \n \n車線幅が大きく変わらないのに車線数が突然\n変化する場合 \n \n<拡大図> \n \n図： 7 無車線区間の入力例'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 40, 'page_label': '41'}, page_content='料金所 \n• 料金所のアノテーション例を示します \n状況 画像例 アノテーション例 \n料金所の\n例 \n  \n図： 8 料金所の入力例  \n踏切 \n• 踏切のアノテーション例を示します \n状況 画像例 アノテーション例 \n交差\n点内\nと接\nして\nいる\n場合'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 41, 'page_label': '42'}, page_content='交差\n点間\nと接\nして\nいる\n場合 \n \n \n図： 9 踏切の入力例  \nその他 \n隣接画像間の頂点吸着について \n• 地物と同様に吸着機能を活用してください'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 42, 'page_label': '43'}, page_content='202311 - 1.3. アノテーション仕様 - 交差点接\n続関係 \n概要 \n 交差点間レーンNW の端点の接続関係を、交差点接続関係として入力します。 \n• 「交差点間レーンNW の区切り（端点）位置」の仕様に基づく端点について、どの端点\n同士が接続を持つか入力します  \no 画像端、見切れ等による仕様外の途切れについては入力対象外です \n• 特に、順方向の交差点間レーンNW について、終点を進入点、始点を退出点と呼び、\n進入点と退出点の組が接続を持ちます \no 両方向、不明の場合は、末端の点のどちらもが進入点、退出点であるとみなし\nます \n画像例 アノテーション例 \n \n \n図： 1 アノテーション例    ** （交差点内）緑線：交差点接続関係'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 43, 'page_label': '44'}, page_content='ラベルの説明 \n交差点接続関係 \n• １進入点から、１方向に対して１退出点の組み合わせを入力します。 \n• ポリラインアノテーションで進入点から退出点へ吸着させて入力します \n• 直進の接続は車線変更不要な1 つの組み合わせを入力します（アノテーション仕様の\n図を参照）。 \n• 左折の場合、進入位置より一番手前の車線から順に入力します。 \n• 右折の場合、進入位置より一番奥の車線から順に入力します。 \n• 接続関係はなるべくシンプルで自然な関係のみとします（アノテーション仕様の図を参\n照）。 \n• 交差点が複数画像に跨って存在する場合、進入点のある画像側で入力します \n• 矢印ペイントが確認できる場合はペイントの進行方向に従って入力します。 （矢印ペイ\nントがない場合は「例）右左折直進の矢印ペイントがない場合」のルールに従う。） \n• 「交差点間レーンNW の区切り（端点）位置」の仕様に基づく端点には、必ず 1 つ以上\nの交差点接続関係を入力します \n \nアノテーション仕様'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 44, 'page_label': '45'}, page_content=''),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 45, 'page_label': '46'}, page_content=''),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 46, 'page_label': '47'}, page_content=''),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 47, 'page_label': '48'}, page_content='その他 \n対応する接続が存在しない場合 \n• 対応する接続が存在しない場合（進入点、退出点のどちらについても）、見えている端\n点側にのみ吸着する接続関係を 1 つ入力します \n図 補足 \n \n図中の赤丸内について  \n• 直進方向は対象外領\n域のため対応があり\nません \n• 左折側は画像の見切\nれにより対応がありま\nせん \n• 該当の車線は右折方\n向の接続を持ちませ\nん \n• 付与できる接続関係\nが 0 件になります \n• そのため、見えている\n端点側にのみ吸着す\nる接続関係を 1 つアノ\nテーションします \n• 入力方法は、吸着し\nていればどの様に入\n力しても良いです \n• 例では、進入点のケ\nースを記載しています\nが、退出点側に接続\nが存在しない場合に\nは、退出点側にも入\n力が必要です \n図： 2 \n進行方向が両方向、不明の接続 \n• 進行方向が両方向、不明の交差点間レーンNW の接続関係を入力する場合、進入と\n退出の両方の接続関係を入力します'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 48, 'page_label': '49'}, page_content='• 両方向、不明同士の接続関係を入力する場合、双方に2 つの接続関\n係を入力します \nアノテーション例 備考 \n \n• 進入と退出の両方の接続関係を入力し\nます（それぞれ１本ずつポリライン入力） \n \n• ①の接続関係：1 車線対面通行（レーン\nNW=両同士）の場合、双方向にそれぞれ\nの接続関係を入力します \no 始点終点が異なるポリラインを 2\n本入力 \n• ②③の接続関係：レーンNW＝不明と両\nとの接続の場合、双方向に接続関係を\n入力します \no 始点終点が異なるポリラインを 2\n本入力 \n図： 3  \n非優先道路（脇道等）から優先道路への接続 \n• 非優先道路から見て優先道路の奥側に交差点間レーンNW の端点が存在しない場\n合、手前側の端点を持つ交差点間レーンNW への接続関係のみ入力します \n• 非優先道路から見て優先道路の奥側の道路にも交差点間レーンNW の端点が存在す\nる場合（区画線の途切れ、道路の拡幅等による）、奥側の交差点間レーンNW へも接\n続関係を入力します \n状況 画像例 アノテーション例'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 49, 'page_label': '50'}, page_content='奥側\nに交\n差点\n間レー\nンNW\nの端\n点が\n存在し\nない場\n合 \n  \n奥側\nに交\n差点\n間レー\nンNW\nの端\n点が\n存在\nする場\n合 \n \n \n図： 4'),
#  Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe Acrobat Standard 2017 17.8.30051', 'creationdate': '2023-12-11T15:57:57+09:00', 'moddate': '2023-12-11T15:57:57+09:00', 'title': '', 'source': '/home/nomuram/azure-chat-search-for-tmi/data/202311_オルソ画像アノテーション仕様書.pdf', 'total_pages': 51, 'page': 50, 'page_label': '51'}, page_content='道路交差がなく、横断歩道、停止線がある場合 \n• 道路の交差がないが、横断歩道、停止線がある場合は交差点接続関係で入力します \n \n交差点ではないが、交差点接続関係で扱う')]
